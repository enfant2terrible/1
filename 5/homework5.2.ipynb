# %%
#Shapiro-Wilk Test - использование на небольшом наборе (до 50 выборок)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Africa = pd.read_csv('Africa.csv')

# %%
Africa
# Out:
#                 Country Name Country Code  \
# 0                     Angola          AGO
# 1                    Burundi          BDI
# 2                      Benin          BEN
# 3                   Botswana          BWA
# 4   Central African Republic          CAF
# 5              Cote d'Ivoire          CIV
# 6                   Cameroon          CMR
# 7           Congo, Dem. Rep.          COD
# 8                Congo, Rep.          COG
# 9                    Comoros          COM
# 10                Cabo Verde          CPV
# 11                  Djibouti          DJI
# 12                   Algeria          DZA
# 13          Egypt, Arab Rep.          EGY
# 14                  Ethiopia          ETH
# 15                     Gabon          GAB
# 16                     Ghana          GHA
# 17                    Guinea          GIN
# 18               Gambia, The          GMB
# 19             Guinea-Bissau          GNB
# 20         Equatorial Guinea          GNQ
# ...

# %%
Africa.describe().transpose()
# Out:
#          count       mean        std   min     25%    50%      75%        max
# percent   50.0  28.545265  23.740471  0.44  15.045  23.34  36.6325  153.44325

# %%
#мы исследуем Экспорт товаров и услуг (% ВВП) - Exports of goods and services (% of GDP) африканских стран на 2020 г.

# %%
Africa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    50 non-null     object
#  1   Country Code    50 non-null     object
#  2   Indicator Name  50 non-null     object
#  3   percent         50 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 1.7+ KB

# %%
import matplotlib
from matplotlib import pyplot 
# %matplotlib inline
pyplot.figure(figsize=(14,6))
pyplot.hist(Africa['percent'])
pyplot.show()

# %%
from scipy.stats import shapiro

DataToTest = Africa['percent']

stat, p = shapiro(DataToTest)

print('stat=%.2f, p=%.30f' % (stat, p))

if p > 0.05:
    print('Normal distribution')
else:
    print('Not a normal distribution')
# Out:
# stat=0.73, p=0.000000030679576212833126191981
# Not a normal distribution

# %%
from scipy import stats

data = Africa['percent']
stats.probplot(data, dist="norm", plot=plt)
print("Shapiro-Wilk test for normality:", stats.shapiro(data))
plt.show()
# Out:
# Shapiro-Wilk test for normality: ShapiroResult(statistic=0.7306523323059082, pvalue=3.0679576212833126e-08)
