# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import seaborn as sns

# %%
df_hr = pd.read_csv('HREmployeeAttrition.csv')

# %%
df_hr
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
print(df_hr.shape)

# размерность данных
# Out:
# (1470, 35)

# %%
print(df_hr.columns)

#имена столбцов
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_hr.describe(include=["object", "bool"])

# In order to see statistics on non-numerical features, one has to explicitly indicate data types of interest in the include parameter
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
df_hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
# делаем вывод: данные уже прошли чистку и готовы к обработке

# %%
full_data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# функция any() возвращает значение True, если в данных присутствует хотя бы одно отсутствующее значение
# The function dataframe.isnull().sum().sum() returns the number of missing values in the data set

# %%
df_hr.apply(np.min)

# Метод apply также можно использовать для применения функции к каждой строке. (np.min) эта функция дает нам данные, которые самые низкие для каждой категории
# Out:
# Age                                                18
# Attrition                                           0
# BusinessTravel                             Non-Travel
# DailyRate                                         102
# Department                            Human Resources
# DistanceFromHome                                    1
# Education                                           1
# EducationField                        Human Resources
# EmployeeCount                                       1
# EmployeeNumber                                      1
# EnvironmentSatisfaction                             1
# Gender                                              0
# HourlyRate                                         30
# JobInvolvement                                      1
# JobLevel                                            1
# JobRole                     Healthcare Representative
# JobSatisfaction                                     1
# ...

# %%
df_hr.apply(np.max)
# Out:
# Age                                           60
# Attrition                                      1
# BusinessTravel                     Travel_Rarely
# DailyRate                                   1499
# Department                                 Sales
# DistanceFromHome                              29
# Education                                      5
# EducationField                  Technical Degree
# EmployeeCount                                  1
# EmployeeNumber                              2068
# EnvironmentSatisfaction                        4
# Gender                                         1
# HourlyRate                                   100
# JobInvolvement                                 4
# JobLevel                                       5
# JobRole                     Sales Representative
# JobSatisfaction                                4
# MaritalStatus                             Single
# MonthlyIncome                              19999
# ...

# %%
full_data.Age.describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=df_hr["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
df_hr['Attrition'].sum()
# Out:
# '...'

# %%
# невозможно работать с такой формой данных, поэтому мы преобразуем их в двоичный код

# %%
df_hr.Attrition.replace(['No','Yes'],[1,0],inplace=True)
df_hr.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          0      Travel_Rarely       1102                   Sales
# 1   49          1  Travel_Frequently        279  Research & Development
# 2   37          0      Travel_Rarely       1373  Research & Development
# 3   33          1  Travel_Frequently       1392  Research & Development
# 4   27          1      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# мы сделаем то же самое с gender

# %%
df_hr.Gender.replace(['Male','Female'],[1,0],inplace=True)
df_hr.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          0      Travel_Rarely       1102                   Sales
# 1   49          1  Travel_Frequently        279  Research & Development
# 2   37          0      Travel_Rarely       1373  Research & Development
# 3   33          1  Travel_Frequently       1392  Research & Development
# 4   27          1      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
df_hr['Attrition'].sum()
# Out:
# 1233

# %%
# 1233 работают

# %%
df_hr['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df_hr.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.838776   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     1.000000   465.000000          2.000000     2.000000
# 50%      36.000000     1.000000   802.000000          7.000000     3.000000
# 75%      43.000000     1.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction       Gender  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769     0.600000
# ...

# %%
df_hr.corr()
# Out:
#                                Age  Attrition  DailyRate  DistanceFromHome  \
# Age                       1.000000   0.159205   0.010661         -0.001686
# Attrition                 0.159205   1.000000   0.056652         -0.077924
# DailyRate                 0.010661   0.056652   1.000000         -0.004985
# DistanceFromHome         -0.001686  -0.077924  -0.004985          1.000000
# Education                 0.208034   0.031373  -0.016806          0.021042
# EmployeeCount                  NaN        NaN        NaN               NaN
# EmployeeNumber           -0.010145   0.010577  -0.050990          0.032916
# EnvironmentSatisfaction   0.010146   0.103369   0.018355         -0.016075
# Gender                   -0.036311  -0.029453  -0.011716         -0.001851
# HourlyRate                0.024287   0.006846   0.023381          0.031131
# JobInvolvement            0.029820   0.130016   0.046135          0.008783
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_hr.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="pastel")

# %%
# не нужно будет использовать все столбцы в этом наборе данных
# будет новый фрейм данных для хранения только тех данных, которые хотим проанализировать

# %%
employee_data = full_data[["Age",
                        "Attrition",
                        "BusinessTravel",
                        "Department",
                        "DistanceFromHome",
                        "Education",
                        "EducationField",
                        "OverTime",
                        "Gender",
                        "JobInvolvement",
                        "JobRole",
                        "JobSatisfaction",
                        "MonthlyIncome",
                        "PerformanceRating",
                        "YearsAtCompany",
                        "YearsInCurrentRole",
                        "YearsSinceLastPromotion"]]
employee_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField OverTime  Gender  JobInvolvement  \
# 0          2  Life Sciences      Yes  Female               3
# 1          1  Life Sciences       No    Male               2
# 2          2          Other      Yes    Male               2
# 3          4  Life Sciences      Yes  Female               3
# 4          1        Medical       No    Male               3
#
#                  JobRole  JobSatisfaction  MonthlyIncome  PerformanceRating  \
# ...

# %%
names = ["JobInvolvement", "JobSatisfaction", "PerformanceRating"]

for name in names:
    employee_data[name].replace({1 : "Low",
                                    2 : "Medium",
                                    3 : "High",
                                    4 : "Very High"}, inplace = True)
employee_data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField OverTime  Gender JobInvolvement  \
# 0          2  Life Sciences      Yes  Female           High
# 1          1  Life Sciences       No    Male         Medium
# 2          2          Other      Yes    Male         Medium
# 3          4  Life Sciences      Yes  Female           High
# 4          1        Medical       No    Male           High
#
#                  JobRole JobSatisfaction  MonthlyIncome PerformanceRating  \
# ...

# %%
sns.boxplot(x=df_hr["MonthlyIncome"])
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
ax = sns.boxplot(data = employee_data,
           y = "Gender",
           x = "MonthlyIncome",
           palette = "muted")

ax.set_xlabel("Monthly Income [$ USD]", labelpad = 25)
ax.set_ylabel(None)
ax.set_title("Monthly Income by Gender", pad = 35)
# Out:
# Text(0.5, 1.0, 'Monthly Income by Gender')

# %%
ax = sns.histplot(data = employee_data,
            x = "Age",
            hue = "Attrition",
            palette = "muted")

ax.set_title("Age of Employees", pad = 45)
ax.set_ylabel(None)
ax.set_xlabel("Age in Years", labelpad = 25)

plt.text(x = 45, y = 110, s =  "Average age is 37 years", fontweight = 'semibold')
# Out:
# Text(45, 110, 'Average age is 37 years')

# %%
ax = sns.kdeplot(x = employee_data.loc[employee_data.Attrition == "No"].YearsAtCompany, label = "Still Employed", color = "steelblue")
ax = sns.kdeplot(x = employee_data.loc[employee_data.Attrition == "Yes"].YearsAtCompany, label = "Left Company", color = "red")
ax.set_title("Years at Company", pad = 35)
ax.set_xlabel("Years")
ax.legend()

# %%
def plot_stats(column, title, label):
    
    fig, ax = plt.subplots(1,2, figsize = (20, 9))

    sns.countplot(ax = ax[0], 
                 data = employee_data.loc[employee_data.Attrition == "Yes"],
                 x = column,
                 order = ['Low', 'Medium', 'High', 'Very High'])

    sns.countplot(ax = ax[1], 
                 data = employee_data.loc[employee_data.Attrition == "No"],
                 x = column,
                 order = ['Low', 'Medium', 'High', 'Very High'])

    fig.suptitle(title, fontsize = 25, y = 1.05)
    ax[0].set_title("Left Company", pad = 35)
    ax[1].set_title("Still Employed", pad = 35)

    for i in [0,1]:
        ax[i].set_ylabel(None)
        ax[i].set_xlabel(label, labelpad = 20)

# %%
plot_stats("JobSatisfaction", "Job Satisfaction by Attrition", "Job Satisfaction")

# %%
plot_stats("JobInvolvement", "Job Involvement by Attrition", "Job Involvement")

# %%
plot_stats("PerformanceRating", "Performance Rating by Attrition", "Performance Rating")

# %%
#ключевые выводы:
#0: данные чистые и готовы к использованию
#1: в компании 1233 активных сотрудника; больше мужчин; большинство сотрудников в R&D (961) - рабочая роль: Sales representative; нижний возрастной предел для сотрудников - 18 лет, верхний - 60 лет; самая высокая зарплата почти в 20 раз выше минимальной; средний возраст составляет 37 лет
#2: с точки зрения заработной платы медиана составляет примерно 5000$, в котором женщинам платят больше, чем мужчинам (небольшая разница)
#3: похоже, что большинству сотрудников, которые покидают компанию, меньше 40 лет; сотрудники, которые покидают компанию, похоже, не проводят в ней много времени; как и ожидалось, сотрудники, которые сообщают о низкой удовлетворенности работой, способствуют истощению; oднако мы видим наибольшее количество увольнений со стороны сотрудников, которые сообщают о высоком уровне удовлетворенности работой
